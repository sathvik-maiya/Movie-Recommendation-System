# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Extracting features of 2018 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1._append(df2._append(df3._append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                       Title  \
# 0      J A N U A R Y          5     Insidious: The Last Key
# 1      J A N U A R Y          5            The Strange Ones
# 2      J A N U A R Y          5                    Stratton
# 3      J A N U A R Y         10               Sweet Country
# 4      J A N U A R Y         12                The Commuter
# ..               ...        ...                         ...
# 270  D E C E M B E R         25             Holmes & Watson
# 271  D E C E M B E R         25                        Vice
# 272  D E C E M B E R         25         On the Basis of Sex
# 273  D E C E M B E R         25                   Destroyer
# 274  D E C E M B E R         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                        Momentum Pictures / GFM Films
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 270  Columbia Pictures / Gary Sanchez Productions /...
# 271          Annapurna Pictures / Plan B Entertainment
# 272                                     Focus Features
# 273                                 Annapurna Pictures
# 274                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# 273  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 274  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 270  [164]
# 271  [137]
# 272  [230]
# 273  [263]
# 274  [264]
#
# [275 rows x 7 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '6c83313bc5dec703b3357010c1b2dff9'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#              Opening  Opening.1                       Title  \
# 0      J A N U A R Y          5     Insidious: The Last Key
# 1      J A N U A R Y          5            The Strange Ones
# 2      J A N U A R Y          5                    Stratton
# 3      J A N U A R Y         10               Sweet Country
# 4      J A N U A R Y         12                The Commuter
# ..               ...        ...                         ...
# 270  D E C E M B E R         25             Holmes & Watson
# 271  D E C E M B E R         25                        Vice
# 272  D E C E M B E R         25         On the Basis of Sex
# 273  D E C E M B E R         25                   Destroyer
# 274  D E C E M B E R         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                        Momentum Pictures / GFM Films
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 270  Columbia Pictures / Gary Sanchez Productions /...
# 271          Annapurna Pictures / Plan B Entertainment
# 272                                     Focus Features
# 273                                 Annapurna Pictures
# 274                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# 273  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 274  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 270  [164]
# 271  [137]
# 272  [230]
# 273  [263]
# 274  [264]
#
# [275 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_2018 = df[['Title','Cast and crew','genres']]
#
# File c:\Users\sathvik v maiya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\sathvik v maiya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File c:\Users\sathvik v maiya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['genres'] not in index"

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 263             Holmes & Watson
# 264                        Vice
# 265         On the Basis of Sex
# 266                   Destroyer
# 267  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 263  Etan Cohen (director/screenplay); Will Ferrell...
# 264  Adam McKay (director/screenplay); Christian Ba...
# 265  Mimi Leder (director); Daniel Stiepleman (scre...
# 266  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 267  David Slade (director); Charlie Brooker (scree...
#
#                                               genres
# 0                            Mystery Horror Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                                    Action Thriller
# ..                                               ...
# 263                   Mystery Adventure Comedy Crime
# 264        Thriller Science Fiction Action Adventure
# 265                                    Drama History
# 266                      Thriller Crime Drama Action
# 267  Science Fiction Mystery Drama Thriller TV Movie
#
# [268 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\sathvik v maiya\AppData\Local\Temp\ipykernel_15456\930721595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
       if len((x.split("screenplay); ")[-1]).split(", ")) < 1:
           return np.NaN
       else:
              return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                     movie_title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# 273  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 274  David Slade (director); Charlie Brooker (scree...
#
#                                               genres       director_name  \
# 0                            Horror Mystery Thriller        Adam Robitel
# 1                                     Thriller Drama    Lauren Wolkstein
# 2                                    Action Thriller          Simon West
# 3                       Western Crime Thriller Drama    Warwick Thornton
# 4                            Action Thriller Mystery  Jaume Collet-Serra
# ..                                               ...                 ...
# 270                   Mystery Adventure Comedy Crime          Etan Cohen
# 271        Thriller Science Fiction Action Adventure          Adam McKay
# 272                                    Drama History          Mimi Leder
# 273                      Thriller Crime Drama Action        Karyn Kusama
# 274  Science Fiction Mystery Drama Thriller TV Movie         David Slade
#
#         actor_1_name            actor_2_name    actor_3_name
# 0          Lin Shaye           Angus Sampson  Leigh Whannell
# 1      Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2     Dominic Cooper          Austin Stowell      Gemma Chan
# 3        Bryan Brown               Sam Neill             NaN
# 4        Liam Neeson            Vera Farmiga  Patrick Wilson
# ..               ...                     ...             ...
# 270     Will Ferrell          John C. Reilly    Rebecca Hall
# 271   Christian Bale               Amy Adams    Steve Carell
# 272   Felicity Jones            Armie Hammer  Justin Theroux
# 273    Nicole Kidman          Sebastian Stan    Toby Kebbell
# 274  Fionn Whitehead            Will Poulter   Asim Chaudhry
#
# [275 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 270          Etan Cohen     Will Ferrell          John C. Reilly
# 271          Adam McKay   Christian Bale               Amy Adams
# 272          Mimi Leder   Felicity Jones            Armie Hammer
# 273        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 274         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3               NaN                     Western Crime Thriller Drama
# 4    Patrick Wilson                          Action Thriller Mystery
# ..              ...                                              ...
# 270    Rebecca Hall                   Mystery Adventure Comedy Crime
# 271    Steve Carell        Thriller Science Fiction Action Adventure
# 272  Justin Theroux                                    Drama History
# 273    Toby Kebbell                      Thriller Crime Drama Action
# 274   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
# [275 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 270          Etan Cohen     Will Ferrell          John C. Reilly
# 271          Adam McKay   Christian Bale               Amy Adams
# 272          Mimi Leder   Felicity Jones            Armie Hammer
# 273        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 274         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3           unknown                     Western Crime Thriller Drama
# 4    Patrick Wilson                          Action Thriller Mystery
# ..              ...                                              ...
# 270    Rebecca Hall                   Mystery Adventure Comedy Crime
# 271    Steve Carell        Thriller Science Fiction Action Adventure
# 272  Justin Theroux                                    Drama History
# 273    Toby Kebbell                      Thriller Crime Drama Action
# 274   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title  \
# 0       insidious: the last key
# 1              the strange ones
# 2                      stratton
# 3                 sweet country
# 4                  the commuter
# ..                          ...
# 270             holmes & watson
# 271                        vice
# 272         on the basis of sex
# 273                   destroyer
# 274  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 270  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 271  Christian Bale Amy Adams Steve Carell Adam McK...
# 272  Felicity Jones Armie Hammer Justin Theroux Mim...
# 273  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 274  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [275 rows x 7 columns]

# %% [markdown]
# ## Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df = df1._append(df2._append(df3._append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = df1._append(df2._append(df3._append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
#
# NameError: name 'df1' is not defined

# %%
df
# Out:
#              Opening  Opening.1                Title  \
# 0          A P R I L        5.0              Shazam!
# 1          A P R I L        5.0         Pet Sematary
# 2          A P R I L        5.0  The Best of Enemies
# 3          A P R I L        5.0            High Life
# 4          A P R I L        5.0        Unicorn Store
# ..               ...        ...                  ...
# 192  D E C E M B E R       25.0         Little Women
# 193  D E C E M B E R       25.0                 1917
# 194  D E C E M B E R       25.0           Just Mercy
# 195  D E C E M B E R       27.0             Clemency
# 196              NaN        NaN                  NaN
#
#                                     Production company  \
# 0    Warner Bros. Pictures / New Line Cinema / DC F...
# 1                  Paramount Pictures / Room 101, Inc.
# 2                                    STX Entertainment
# 3                    A24 / Arte / ZDF / Canal+ / Ciné+
# 4                                              Netflix
# ..                                                 ...
# 192            Columbia Pictures / Regency Enterprises
# 193           Universal Pictures / DreamWorks Pictures
# 194          Warner Bros. Pictures / Participant Media
# 195                                               Neon
# 196                                                NaN
#
#                                          Cast and crew   Ref.  \
# 0    David F. Sandberg (director); Henry Gayden (sc...   [51]
# 1    Kevin Kolsch, Dennis Widmyer (directors); Jeff...   [52]
# 2    Robin Bissell (director/screenplay); Taraji P....   [53]
# 3    Claire Denis (director/screenplay); Jean-Pol F...   [54]
# 4    Brie Larson (director); Samantha McIntyre (scr...    NaN
# ..                                                 ...    ...
# 192  Greta Gerwig (director/screenplay); Saoirse Ro...  [224]
# 193  Sam Mendes (director/screenplay); Krysty Wilso...  [225]
# 194  Destin Daniel Cretton (director/screenplay), A...  [226]
# 195  Chinonye Chukwu (director/screenplay); Alfre W...  [227]
# 196                                                NaN    NaN
#
#     .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte2019 films  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196  American Argentine Australian Bangladeshi Braz...
#
#     .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte2019 films.1
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196  American Argentine Australian Bangladeshi Braz...
#
# [197 rows x 8 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019=df.dropna(how='all', axis=1)

# %%
df_2019
# Out:
#                    Title                                      Cast and crew  \
# 0                Shazam!  David F. Sandberg (director); Henry Gayden (sc...
# 1           Pet Sematary  Kevin Kolsch, Dennis Widmyer (directors); Jeff...
# 2    The Best of Enemies  Robin Bissell (director/screenplay); Taraji P....
# 3              High Life  Claire Denis (director/screenplay); Jean-Pol F...
# 4          Unicorn Store  Brie Larson (director); Samantha McIntyre (scr...
# ..                   ...                                                ...
# 192         Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 193                 1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 194           Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 195             Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
# 196                  NaN                                                NaN
#
#                             genres
# 0            Comedy Action Fantasy
# 1                     Horror Drama
# 2                    Drama History
# 3    Science Fiction Drama Mystery
# 4             Fantasy Drama Comedy
# ..                             ...
# 192          Drama Romance History
# 193              War Drama History
# 194            Drama Crime History
# 195                          Drama
# 196                    Drama Crime
#
# [197 rows x 3 columns]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\sathvik v maiya\AppData\Local\Temp\ipykernel_15456\203239715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\sathvik v maiya\AppData\Local\Temp\ipykernel_15456\4159704998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\sathvik v maiya\AppData\Local\Temp\ipykernel_15456\2488206858.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(str(x)))
# Out:
# C:\Users\sathvik v maiya\AppData\Local\Temp\ipykernel_15456\3382287667.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#                     director_name       actor_1_name          actor_2_name  \
# 0               David F. Sandberg       Zachary Levi           Asher Angel
# 1    Kevin Kolsch, Dennis Widmyer       Jason Clarke           Amy Seimetz
# 2                   Robin Bissell   Taraji P. Henson          Sam Rockwell
# 3                    Claire Denis   Robert Pattinson      Juliette Binoche
# 4                     Brie Larson        Brie Larson     Samuel L. Jackson
# ..                            ...                ...                   ...
# 192                  Greta Gerwig      Saoirse Ronan           Emma Watson
# 193                    Sam Mendes      George MacKay  Dean-Charles Chapman
# 194         Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 195               Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 196                           nan                nan               unknown
#
#        actor_3_name                         genres          movie_title  \
# 0       Mark Strong          Comedy Action Fantasy              shazam!
# 1      John Lithgow                   Horror Drama         pet sematary
# 2           unknown                  Drama History  the best of enemies
# 3    André Benjamin  Science Fiction Drama Mystery            high life
# 4       Joan Cusack           Fantasy Drama Comedy        unicorn store
# ..              ...                            ...                  ...
# 192   Florence Pugh          Drama Romance History         little women
# 193     Mark Strong              War Drama History                 1917
# 194     Brie Larson            Drama Crime History           just mercy
# 195     Aldis Hodge                          Drama             clemency
# 196         unknown                    Drama Crime                  NaN
#
#                                                   comb
# 0    Zachary Levi Asher Angel Mark Strong David F. ...
# 1    Jason Clarke Amy Seimetz John Lithgow Kevin Ko...
# 2    Taraji P. Henson Sam Rockwell unknown Robin Bi...
# 3    Robert Pattinson Juliette Binoche André Benjam...
# 4    Brie Larson Samuel L. Jackson Joan Cusack Brie...
# ..                                                 ...
# 192  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 193  George MacKay Dean-Charles Chapman Mark Strong...
# 194  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 195  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 196                nan unknown unknown nan Drama Crime
#
# [197 rows x 7 columns]

# %%
my_df = new_df18._append(new_df19,ignore_index=True)

# %%
my_df
# Out:
#              director_name       actor_1_name            actor_2_name  \
# 0             Adam Robitel          Lin Shaye           Angus Sampson
# 1         Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2               Simon West     Dominic Cooper          Austin Stowell
# 3         Warwick Thornton        Bryan Brown               Sam Neill
# 4       Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                     ...                ...                     ...
# 467           Greta Gerwig      Saoirse Ronan             Emma Watson
# 468             Sam Mendes      George MacKay    Dean-Charles Chapman
# 469  Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 470        Chinonye Chukwu      Alfre Woodard          Wendell Pierce
# 471                    nan                nan                 unknown
#
#        actor_3_name                        genres              movie_title  \
# 0    Leigh Whannell       Horror Mystery Thriller  insidious: the last key
# 1     Emily Althaus                Thriller Drama         the strange ones
# 2        Gemma Chan               Action Thriller                 stratton
# 3           unknown  Western Crime Thriller Drama            sweet country
# 4    Patrick Wilson       Action Thriller Mystery             the commuter
# ..              ...                           ...                      ...
# 467   Florence Pugh         Drama Romance History             little women
# 468     Mark Strong             War Drama History                     1917
# 469     Brie Larson           Drama Crime History               just mercy
# 470     Aldis Hodge                         Drama                 clemency
# 471         unknown                   Drama Crime                      NaN
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 467  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 468  George MacKay Dean-Charles Chapman Mark Strong...
# 469  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 470  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 471                nan unknown unknown nan Drama Crime
#
# [472 rows x 7 columns]

# %%
old_df = pd.read_csv('movie.csv')

# %%
old_df
# Out:
#          director_name     actor_1_name    actor_2_name     actor_3_name  \
# 0        John Lasseter        Tom Hanks       Tim Allen      Don Rickles
# 1         Joe Johnston   Robin Williams   Jonathan Hyde    Kirsten Dunst
# 2        Howard Deutch   Walter Matthau     Jack Lemmon      Ann-Margret
# 3      Forest Whitaker  Whitney Houston  Angela Bassett   Loretta Devine
# 4        Charles Shyer     Steve Martin    Diane Keaton     Martin Short
# ...                ...              ...             ...              ...
# 36336         Ben Rock       Monty Bane     Lucy Butler    David Grammer
# 36337    Aaron Osborne       Lisa Boyle       Kena Land    Zaneta Polard
# 36338       John Irvin   Patrick Bergin     Uma Thurman  David Morrissey
# 36339         Lav Diaz     Angel Aquino     Perry Dizon    Hazel Orencio
# 36340   Mark L. Lester    Erika Eleniak    Adam Baldwin    Julie du Page
#
#                          genres                  movie_title  \
# 0       Animation Comedy Family                    toy story
# 1      Adventure Fantasy Family                      jumanji
# 2                Romance Comedy             grumpier old men
# 3          Comedy Drama Romance            waiting to exhale
# 4                        Comedy  father of the bride part ii
# ...                         ...                          ...
# 36336                    Horror          the burkittsville 7
# 36337                    Sci-Fi              caged heat 3000
# 36338      Drama Action Romance                   robin hood
# 36339                     Drama          century of birthing
# 36340     Action Drama Thriller                     betrayal
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 36336  Monty Bane Lucy Butler David Grammer Ben Rock ...
# 36337  Lisa Boyle Kena Land Zaneta Polard Aaron Osbor...
# 36338  Patrick Bergin Uma Thurman David Morrissey Joh...
# 36339  Angel Aquino Perry Dizon Hazel Orencio Lav Dia...
# 36340  Erika Eleniak Adam Baldwin Julie du Page Mark ...
#
# [36341 rows x 7 columns]

# %%
final_df = old_df._append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              John Lasseter          Tom Hanks             Tim Allen
# 1               Joe Johnston     Robin Williams         Jonathan Hyde
# 2              Howard Deutch     Walter Matthau           Jack Lemmon
# 3            Forest Whitaker    Whitney Houston        Angela Bassett
# 4              Charles Shyer       Steve Martin          Diane Keaton
# ...                      ...                ...                   ...
# 36808           Greta Gerwig      Saoirse Ronan           Emma Watson
# 36809             Sam Mendes      George MacKay  Dean-Charles Chapman
# 36810  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 36811        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 36812                    nan                nan               unknown
#
#          actor_3_name                    genres                  movie_title  \
# 0         Don Rickles   Animation Comedy Family                    toy story
# 1       Kirsten Dunst  Adventure Fantasy Family                      jumanji
# 2         Ann-Margret            Romance Comedy             grumpier old men
# 3      Loretta Devine      Comedy Drama Romance            waiting to exhale
# 4        Martin Short                    Comedy  father of the bride part ii
# ...               ...                       ...                          ...
# 36808   Florence Pugh     Drama Romance History                 little women
# 36809     Mark Strong         War Drama History                         1917
# 36810     Brie Larson       Drama Crime History                   just mercy
# 36811     Aldis Hodge                     Drama                     clemency
# 36812         unknown               Drama Crime                          NaN
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 36808  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 36809  George MacKay Dean-Charles Chapman Mark Strong...
# 36810  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 36811  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 36812                nan unknown unknown nan Drama Crime
#
# [36813 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      1
# comb             0
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.to_csv('final_data.csv',index=False)
